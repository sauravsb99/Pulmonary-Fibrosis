# %% [markdown]
# # 1. End-to-end model: CT scans latent features + Tabular features
# This model is a simple end-to-end solution that uses CT scans latent features and tabular features to generate predictions.
#
# The CT scans latent features are obtained by encoding pre-processed 3D CT scan tensors, using a pre-trained AutoEncoder for that.
#
# The tabular features are obtained by pre-processing the tabular data (more about it [here](https://www.kaggle.com/carlossouza/quantile-regression-pytorch-tabular-data-only)).
#
# I am not including here the code used to train the AutoEncoder. I pretrained it in another notebook, and saved the weights in a [public dataset](https://www.kaggle.com/carlossouza/osicautoencoder).
#
# The overal model looks like the image below:
# ![image](https://i.ibb.co/N65VVMp/final-5f18d00d86a6870013068112-270220.gif)
#
# This version runs on CPU, end-to-end. However, it is slow. Improvements/next steps at the end.

# %% [markdown]
# # 2. Imports and global variables

# %%
use_TPU = False
# use_TPU = True

# %%
if use_TPU:
    # !curl https://raw.githubusercontent.com/pytorch/xla/master/contrib/scripts/env-setup.py -o pytorch-xla-env-setup.py
    # !python pytorch-xla-env-setup.py --version nightly --apt-packages libomp5 libopenblas-dev

# %%
if use_TPU:
    import torch_xla
    import torch_xla.debug.metrics as met
    import torch_xla.distributed.parallel_loader as pl
    import torch_xla.utils.utils as xu
    import torch_xla.core.xla_model as xm
    import torch_xla.distributed.xla_multiprocessing as xmp
    import torch_xla.test.test_utils as test_utils

    import warnings
    warnings.filterwarnings("ignore")

# %%
if use_TPU:
    # !export XLA_USE_BF16=1

# %%
# !pip install pydicom
# Out:
# Collecting pydicom
#   Downloading https://files.pythonhosted.org/packages/f4/15/df16546bc59bfca390cf072d473fb2c8acd4231636f64356593a63137e55/pydicom-2.1.2-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 3.8MB/s
# Installing collected packages: pydicom
# Successfully installed pydicom-2.1.2

# %%
import copy
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import pandas as pd
from pathlib import Path
import pickle
import pydicom
from sklearn.model_selection import GroupKFold, GroupShuffleSplit
from torch.utils.data import Dataset
from tqdm import tqdm
import torch
from torch.utils.data import DataLoader, Subset
import torch.nn as nn
import torch.nn.functional as F
from tqdm import trange
from time import time
import warnings
from scipy.ndimage.interpolation import zoom
from enum import Enum
from torchvision import transforms
from skimage.measure import label, regionprops
from skimage.segmentation import clear_border
import pytest

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/My Drive/PulmonaryFibrosis/archive_updated.zip" -d "/content/osic-cached-dataset/"
# !unzip "/content/drive/My Drive/PulmonaryFibrosis/osic-pulmonary-fibrosis-progression.zip" -d "/content/osic-pulmonary-fibrosis-progression/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/139.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/14.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/140.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/141.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/142.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/143.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/144.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/145.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/146.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/147.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/148.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/149.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/15.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/150.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/151.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/152.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/153.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/154.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/155.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/156.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/157.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/158.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/159.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/16.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/160.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/161.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/162.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/163.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/164.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/165.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/166.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/167.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/168.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/169.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/17.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/170.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/171.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/172.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/173.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/174.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/175.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/176.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/177.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/178.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/179.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/18.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/180.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/181.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/182.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/183.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/184.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/185.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/186.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/187.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/188.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/189.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/19.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/190.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/191.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/192.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/193.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/194.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/195.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/196.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/197.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/198.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/199.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/2.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/20.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/200.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/201.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/202.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/203.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/204.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/205.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/206.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/207.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/208.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/209.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/21.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/210.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/211.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/212.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/213.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/214.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/215.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/216.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/217.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/22.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/23.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/24.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/25.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/26.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/27.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/28.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/29.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/3.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/30.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/31.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/32.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/33.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/34.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/35.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/36.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/37.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/38.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/39.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/4.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/40.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/41.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/42.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/43.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/44.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/45.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/46.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/47.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/48.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/49.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/5.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/50.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/51.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/52.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/53.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/54.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/55.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/56.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/57.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/58.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/59.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/6.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/60.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/61.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/62.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/63.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/64.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/65.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/66.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/67.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/68.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/69.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/7.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/70.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/71.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/72.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/73.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/74.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/75.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/76.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/77.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/78.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/79.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/8.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/80.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/81.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/82.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/83.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/84.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/85.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/86.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/87.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/88.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/89.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/9.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/90.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/91.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/92.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/93.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/94.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/95.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/96.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/97.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/98.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151/99.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/1.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/10.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/100.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/101.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/102.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/103.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/104.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/105.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/106.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/107.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/108.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/109.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/11.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/110.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/111.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/112.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/113.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/114.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/115.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/116.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/117.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/118.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/119.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/12.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/120.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/121.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/122.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/123.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/124.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/125.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/126.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/127.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/128.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/129.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/13.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/130.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/131.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/132.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/133.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/134.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/135.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/136.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/137.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/138.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/139.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/14.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/140.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/141.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/142.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/143.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/144.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/145.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/146.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/147.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/148.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/149.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/15.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/150.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/151.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/152.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/153.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/154.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/155.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/156.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/157.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/158.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/159.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/16.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/160.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/161.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/162.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/163.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/164.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/165.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/166.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/167.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/168.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/169.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/17.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/170.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/171.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/172.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/173.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/174.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/175.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/176.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/177.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/178.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/179.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/18.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/180.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/181.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/182.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/183.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/184.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/185.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/186.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/187.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/188.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/189.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/19.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/190.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/191.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/192.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/193.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/194.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/195.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/196.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/197.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/198.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/199.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/2.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/20.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/200.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/201.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/202.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/203.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/204.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/205.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/206.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/207.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/208.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/209.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/21.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/210.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/211.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/212.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/213.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/214.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/215.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/216.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/217.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/218.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/219.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/22.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/220.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/221.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/222.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/223.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/224.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/225.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/226.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/227.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/228.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/229.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/23.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/230.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/231.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/232.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/233.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/234.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/235.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/236.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/237.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/238.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/239.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/24.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/240.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/241.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/242.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/243.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/244.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/245.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/246.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/247.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/248.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/249.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/25.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/250.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/251.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/252.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/253.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/254.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/255.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/256.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/257.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/258.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/259.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/26.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/260.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/261.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/262.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/263.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/264.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/265.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/266.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/267.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/268.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/269.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/27.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/270.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/271.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/272.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/273.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/274.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/275.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/276.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/277.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/278.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/279.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/28.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/280.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/281.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/282.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/283.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/284.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/285.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/286.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/287.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/288.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/289.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/29.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/290.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/291.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/292.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/293.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/294.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/295.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/296.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/297.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/298.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/299.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/3.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/30.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/300.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/301.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/302.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/303.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/304.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/305.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/306.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/307.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/308.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/309.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/31.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/310.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/311.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/312.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/313.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/314.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/315.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/316.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/317.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/318.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/319.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/32.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/320.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/321.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/322.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/323.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/324.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/325.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/326.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/327.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/328.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/329.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/33.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/330.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/331.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/332.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/333.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/334.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/335.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/336.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/337.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/338.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/339.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/34.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/340.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/341.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/342.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/343.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/344.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/345.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/346.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/347.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/348.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/349.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/35.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/350.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/351.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/352.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/353.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/354.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/355.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/356.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/357.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/358.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/359.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/36.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/360.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/361.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/362.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/363.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/364.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/37.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/38.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/39.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/4.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/40.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/41.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/42.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/43.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/44.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/45.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/46.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743/47.dcm
# ...
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/322.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/323.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/324.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/325.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/326.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/327.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/328.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/329.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/33.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/330.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/331.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/332.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/333.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/334.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/335.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/336.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/337.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/338.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/339.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/34.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/340.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/341.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/342.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/343.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/344.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/345.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/346.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/347.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/348.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/349.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/35.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/350.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/351.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/352.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/353.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/354.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/355.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/356.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/357.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/358.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/359.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/36.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/360.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/361.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/362.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/363.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/364.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/365.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/366.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/367.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/368.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/369.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/37.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/370.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/371.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/372.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/373.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/374.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/375.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/376.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/377.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/378.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/379.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/38.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/380.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/381.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/382.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/383.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/384.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/385.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/386.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/387.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/388.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/389.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/39.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/390.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/391.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/392.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/393.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/394.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/395.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/396.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/397.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/398.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/399.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/4.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/40.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/400.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/401.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/402.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/403.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/404.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/405.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/406.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/407.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/408.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/41.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/42.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/43.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/44.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/45.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/46.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/47.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/48.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/49.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/5.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/50.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/51.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/52.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/53.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/54.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/55.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/56.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/57.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/58.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/59.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/6.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/60.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/61.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/62.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/63.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/64.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/65.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/66.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/67.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/68.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/69.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/7.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/70.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/71.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/72.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/73.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/74.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/75.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/76.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/77.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/78.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/79.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/8.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/80.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/81.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/82.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/83.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/84.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/85.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/86.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/87.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/88.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/89.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/9.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/90.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/91.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/92.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/93.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/94.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/95.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/96.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/97.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/98.dcm
#   inflating: /content/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466/99.dcm

# %%
# !cp -r "/content/drive/My Drive/PulmonaryFibrosis/test" "/content/"

# %%
# !cp  "/content/drive/My Drive/PulmonaryFibrosis/cached_osis/features_list.pkl" "/content/osic-cached-dataset/"
# !cp  "/content/drive/My Drive/PulmonaryFibrosis/cached_osis/tabular_test.csv" "/content/osic-cached-dataset/"
# !cp  "/content/drive/My Drive/PulmonaryFibrosis/cached_osis/tabular_train.csv" "/content/osic-cached-dataset/"
# !cp  "/content/drive/My Drive/PulmonaryFibrosis/cached_osis/tabular_val.csv" "/content/osic-cached-dataset/"

# %%
# !unzip "/content/drive/My Drive/PulmonaryFibrosis/results.zip" -d "/content/results/"
# Out:
# Archive:  /content/drive/My Drive/PulmonaryFibrosis/results.zip
#   inflating: /content/results/__results___files/__results___26_1.png
#   inflating: /content/results/cauchy-20200724.csv
#   inflating: /content/results/cauchy-20200724.pth
#   inflating: /content/results/latent/ID00007637202177411956430_lat.pt
#   inflating: /content/results/latent/ID00009637202177434476278_lat.pt
#   inflating: /content/results/latent/ID00010637202177584971671_lat.pt
#   inflating: /content/results/latent/ID00011637202177653955184_lat.pt
#   inflating: /content/results/latent/ID00012637202177665765362_lat.pt
#   inflating: /content/results/latent/ID00014637202177757139317_lat.pt
#   inflating: /content/results/latent/ID00015637202177877247924_lat.pt
#   inflating: /content/results/latent/ID00019637202178323708467_lat.pt
#   inflating: /content/results/latent/ID00020637202178344345685_lat.pt
#   inflating: /content/results/latent/ID00023637202179104603099_lat.pt
#   inflating: /content/results/latent/ID00025637202179541264076_lat.pt
#   inflating: /content/results/latent/ID00026637202179561894768_lat.pt
#   inflating: /content/results/latent/ID00027637202179689871102_lat.pt
#   inflating: /content/results/latent/ID00030637202181211009029_lat.pt
#   inflating: /content/results/latent/ID00032637202181710233084_lat.pt
#   inflating: /content/results/latent/ID00035637202182204917484_lat.pt
#   inflating: /content/results/latent/ID00038637202182690843176_lat.pt
#   inflating: /content/results/latent/ID00042637202184406822975_lat.pt
#   inflating: /content/results/latent/ID00047637202184938901501_lat.pt
#   inflating: /content/results/latent/ID00048637202185016727717_lat.pt
#   inflating: /content/results/latent/ID00051637202185848464638_lat.pt
#   inflating: /content/results/latent/ID00052637202186188008618_lat.pt
#   inflating: /content/results/latent/ID00060637202187965290703_lat.pt
#   inflating: /content/results/latent/ID00061637202188184085559_lat.pt
#   inflating: /content/results/latent/ID00062637202188654068490_lat.pt
#   inflating: /content/results/latent/ID00067637202189903532242_lat.pt
#   inflating: /content/results/latent/ID00068637202190879923934_lat.pt
#   inflating: /content/results/latent/ID00072637202198161894406_lat.pt
#   inflating: /content/results/latent/ID00073637202198167792918_lat.pt
#   inflating: /content/results/latent/ID00075637202198610425520_lat.pt
#   inflating: /content/results/latent/ID00076637202199015035026_lat.pt
#   inflating: /content/results/latent/ID00077637202199102000916_lat.pt
#   inflating: /content/results/latent/ID00078637202199415319443_lat.pt
#   inflating: /content/results/latent/ID00082637202201836229724_lat.pt
#   inflating: /content/results/latent/ID00086637202203494931510_lat.pt
#   inflating: /content/results/latent/ID00089637202204675567570_lat.pt
#   inflating: /content/results/latent/ID00090637202204766623410_lat.pt
#   inflating: /content/results/latent/ID00093637202205278167493_lat.pt
#   inflating: /content/results/latent/ID00094637202205333947361_lat.pt
#   inflating: /content/results/latent/ID00099637202206203080121_lat.pt
#   inflating: /content/results/latent/ID00102637202206574119190_lat.pt
#   inflating: /content/results/latent/ID00104637202208063407045_lat.pt
#   inflating: /content/results/latent/ID00105637202208831864134_lat.pt
#   inflating: /content/results/latent/ID00108637202209619669361_lat.pt
#   inflating: /content/results/latent/ID00109637202210454292264_lat.pt
#   inflating: /content/results/latent/ID00110637202210673668310_lat.pt
#   inflating: /content/results/latent/ID00111637202210956877205_lat.pt
#   inflating: /content/results/latent/ID00115637202211874187958_lat.pt
#   inflating: /content/results/latent/ID00117637202212360228007_lat.pt
#   inflating: /content/results/latent/ID00119637202215426335765_lat.pt
#   inflating: /content/results/latent/ID00122637202216437668965_lat.pt
#   inflating: /content/results/latent/ID00123637202217151272140_lat.pt
#   inflating: /content/results/latent/ID00124637202217596410344_lat.pt
#   inflating: /content/results/latent/ID00125637202218590429387_lat.pt
#   inflating: /content/results/latent/ID00126637202218610655908_lat.pt
#   inflating: /content/results/latent/ID00127637202219096738943_lat.pt
#   inflating: /content/results/latent/ID00128637202219474716089_lat.pt
#   inflating: /content/results/latent/ID00129637202219868188000_lat.pt
#   inflating: /content/results/latent/ID00130637202220059448013_lat.pt
#   inflating: /content/results/latent/ID00131637202220424084844_lat.pt
#   inflating: /content/results/latent/ID00132637202222178761324_lat.pt
#   inflating: /content/results/latent/ID00133637202223847701934_lat.pt
#   inflating: /content/results/latent/ID00134637202223873059688_lat.pt
#   inflating: /content/results/latent/ID00135637202224630271439_lat.pt
#   inflating: /content/results/latent/ID00136637202224951350618_lat.pt
#   inflating: /content/results/latent/ID00138637202231603868088_lat.pt
#   inflating: /content/results/latent/ID00139637202231703564336_lat.pt
#   inflating: /content/results/latent/ID00140637202231728595149_lat.pt
#   inflating: /content/results/latent/ID00149637202232704462834_lat.pt
#   inflating: /content/results/latent/ID00161637202235731948764_lat.pt
#   inflating: /content/results/latent/ID00165637202237320314458_lat.pt
#   inflating: /content/results/latent/ID00167637202237397919352_lat.pt
#   inflating: /content/results/latent/ID00168637202237852027833_lat.pt
#   inflating: /content/results/latent/ID00169637202238024117706_lat.pt
#   inflating: /content/results/latent/ID00170637202238079193844_lat.pt
#   inflating: /content/results/latent/ID00172637202238316925179_lat.pt
#   inflating: /content/results/latent/ID00173637202238329754031_lat.pt
#   inflating: /content/results/latent/ID00180637202240177410333_lat.pt
#   inflating: /content/results/latent/ID00183637202241995351650_lat.pt
#   inflating: /content/results/latent/ID00184637202242062969203_lat.pt
#   inflating: /content/results/latent/ID00186637202242472088675_lat.pt
#   inflating: /content/results/latent/ID00190637202244450116191_lat.pt
#   inflating: /content/results/latent/ID00192637202245493238298_lat.pt
#   inflating: /content/results/latent/ID00196637202246668775836_lat.pt
#   inflating: /content/results/latent/ID00197637202246865691526_lat.pt
#   inflating: /content/results/latent/ID00199637202248141386743_lat.pt
#   inflating: /content/results/latent/ID00202637202249376026949_lat.pt
#   inflating: /content/results/latent/ID00207637202252526380974_lat.pt
#   inflating: /content/results/latent/ID00210637202257228694086_lat.pt
#   inflating: /content/results/latent/ID00213637202257692916109_lat.pt
#   inflating: /content/results/latent/ID00214637202257820847190_lat.pt
#   inflating: /content/results/latent/ID00216637202257988213445_lat.pt
#   inflating: /content/results/latent/ID00218637202258156844710_lat.pt
#   inflating: /content/results/latent/ID00219637202258203123958_lat.pt
#   inflating: /content/results/latent/ID00221637202258717315571_lat.pt
#   inflating: /content/results/latent/ID00222637202259066229764_lat.pt
#   inflating: /content/results/latent/ID00224637202259281193413_lat.pt
#   inflating: /content/results/latent/ID00225637202259339837603_lat.pt
#   inflating: /content/results/latent/ID00228637202259965313869_lat.pt
#   inflating: /content/results/latent/ID00229637202260254240583_lat.pt
#   inflating: /content/results/latent/ID00232637202260377586117_lat.pt
#   inflating: /content/results/latent/ID00233637202260580149633_lat.pt
#   inflating: /content/results/latent/ID00234637202261078001846_lat.pt
#   inflating: /content/results/latent/ID00235637202261451839085_lat.pt
#   inflating: /content/results/latent/ID00240637202264138860065_lat.pt
#   inflating: /content/results/latent/ID00241637202264294508775_lat.pt
#   inflating: /content/results/latent/ID00242637202264759739921_lat.pt
#   inflating: /content/results/latent/ID00248637202266698862378_lat.pt
#   inflating: /content/results/latent/ID00249637202266730854017_lat.pt
#   inflating: /content/results/latent/ID00251637202267455595113_lat.pt
#   inflating: /content/results/latent/ID00255637202267923028520_lat.pt
#   inflating: /content/results/latent/ID00264637202270643353440_lat.pt
#   inflating: /content/results/latent/ID00267637202270790561585_lat.pt
#   inflating: /content/results/latent/ID00273637202271319294586_lat.pt
#   inflating: /content/results/latent/ID00275637202271440119890_lat.pt
#   inflating: /content/results/latent/ID00276637202271694539978_lat.pt
#   inflating: /content/results/latent/ID00279637202272164826258_lat.pt
#   inflating: /content/results/latent/ID00283637202278714365037_lat.pt
#   inflating: /content/results/latent/ID00285637202278913507108_lat.pt
#   inflating: /content/results/latent/ID00288637202279148973731_lat.pt
#   inflating: /content/results/latent/ID00290637202279304677843_lat.pt
#   inflating: /content/results/latent/ID00291637202279398396106_lat.pt
#   inflating: /content/results/latent/ID00294637202279614924243_lat.pt
#   inflating: /content/results/latent/ID00296637202279895784347_lat.pt
#   inflating: /content/results/latent/ID00298637202280361773446_lat.pt
#   inflating: /content/results/latent/ID00299637202280383305867_lat.pt
#   inflating: /content/results/latent/ID00305637202281772703145_lat.pt
#   inflating: /content/results/latent/ID00307637202282126172865_lat.pt
#   inflating: /content/results/latent/ID00309637202282195513787_lat.pt
#   inflating: /content/results/latent/ID00312637202282607344793_lat.pt
#   inflating: /content/results/latent/ID00317637202283194142136_lat.pt
#   inflating: /content/results/latent/ID00319637202283897208687_lat.pt
#   inflating: /content/results/latent/ID00322637202284842245491_lat.pt
#   inflating: /content/results/latent/ID00323637202285211956970_lat.pt
#   inflating: /content/results/latent/ID00329637202285906759848_lat.pt
#   inflating: /content/results/latent/ID00331637202286306023714_lat.pt
#   inflating: /content/results/latent/ID00335637202286784464927_lat.pt
#   inflating: /content/results/latent/ID00336637202286801879145_lat.pt
#   inflating: /content/results/latent/ID00337637202286839091062_lat.pt
#   inflating: /content/results/latent/ID00339637202287377736231_lat.pt
#   inflating: /content/results/latent/ID00340637202287399835821_lat.pt
#   inflating: /content/results/latent/ID00341637202287410878488_lat.pt
#   inflating: /content/results/latent/ID00342637202287526592911_lat.pt
#   inflating: /content/results/latent/ID00343637202287577133798_lat.pt
#   inflating: /content/results/latent/ID00344637202287684217717_lat.pt
#   inflating: /content/results/latent/ID00351637202289476567312_lat.pt
#   inflating: /content/results/latent/ID00355637202295106567614_lat.pt
#   inflating: /content/results/latent/ID00358637202295388077032_lat.pt
#   inflating: /content/results/latent/ID00360637202295712204040_lat.pt
#   inflating: /content/results/latent/ID00364637202296074419422_lat.pt
#   inflating: /content/results/latent/ID00365637202296085035729_lat.pt
#   inflating: /content/results/latent/ID00367637202296290303449_lat.pt
#   inflating: /content/results/latent/ID00368637202296470751086_lat.pt
#   inflating: /content/results/latent/ID00370637202296737666151_lat.pt
#   inflating: /content/results/latent/ID00371637202296828615743_lat.pt
#   inflating: /content/results/latent/ID00376637202297677828573_lat.pt
#   inflating: /content/results/latent/ID00378637202298597306391_lat.pt
#   inflating: /content/results/latent/ID00381637202299644114027_lat.pt
#   inflating: /content/results/latent/ID00383637202300493233675_lat.pt
#   inflating: /content/results/latent/ID00388637202301028491611_lat.pt
#   inflating: /content/results/latent/ID00392637202302319160044_lat.pt
#   inflating: /content/results/latent/ID00393637202302431697467_lat.pt
#   inflating: /content/results/latent/ID00398637202303897337979_lat.pt
#   inflating: /content/results/latent/ID00400637202305055099402_lat.pt
#   inflating: /content/results/latent/ID00401637202305320178010_lat.pt
#   inflating: /content/results/latent/ID00405637202308359492977_lat.pt
#   inflating: /content/results/latent/ID00407637202308788732304_lat.pt
#   inflating: /content/results/latent/ID00408637202308839708961_lat.pt
#   inflating: /content/results/latent/ID00411637202309374271828_lat.pt
#   inflating: /content/results/latent/ID00414637202310318891556_lat.pt
#   inflating: /content/results/latent/ID00417637202310901214011_lat.pt
#   inflating: /content/results/latent/ID00419637202311204720264.dcm
#   inflating: /content/results/latent/ID00419637202311204720264.pt
#   inflating: /content/results/latent/ID00419637202311204720264_lat.pt
#   inflating: /content/results/latent/ID00421637202311550012437.dcm
#   inflating: /content/results/latent/ID00421637202311550012437.pt
#   inflating: /content/results/latent/ID00421637202311550012437_lat.pt
#   inflating: /content/results/latent/ID00422637202311677017371.dcm
#   inflating: /content/results/latent/ID00422637202311677017371.pt
#   inflating: /content/results/latent/ID00422637202311677017371_lat.pt
#   inflating: /content/results/latent/ID00423637202312137826377.dcm
#   inflating: /content/results/latent/ID00423637202312137826377.pt
#   inflating: /content/results/latent/ID00423637202312137826377_lat.pt
#   inflating: /content/results/latent/ID00426637202313170790466.dcm
#   inflating: /content/results/latent/ID00426637202313170790466.pt
#   inflating: /content/results/latent/ID00426637202313170790466_lat.pt
#   inflating: /content/results/latent/features_list.pkl
#   inflating: /content/results/latent/tabular_test.csv
#   inflating: /content/results/submission.csv

# %%
root_dir = Path('/content/osic-pulmonary-fibrosis-progression')
model_dir = Path('/content/working')
pretrained_weigths_dir = Path('/content/test/pretrained_models')
pretrained_ae_weigths = pretrained_weigths_dir/'barcelona-20200722.pth'
cache_dir = Path('/content/osic-cached-dataset')
latent_dir = Path('/content/results/latent')
latent_dir.mkdir(exist_ok=True, parents=True)
# num_kfolds = 5
test_size=0.2
batch_size = 100
learning_rate = 1e-3
num_epochs = 20
quantiles = (0.2, 0.5, 0.8)
model_name ='cauchy'

# if use_TPU:
#     device = xm.xla_device()
# else:
#     device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # 3. Dataset interface
# Now, the dataset interface not only ingests the tabular data, but also ingests and pre-process the 3D CT scans. The changes vs. [the baseline notebook](https://www.kaggle.com/carlossouza/quantile-regression-pytorch-tabular-data-only) are highlighted in the code.
#
# On the code below, again credits to [Ulrich GOUE](https://www.kaggle.com/ulrich07).
#
# The key trick here is to cache all tensors in disk, otherwise training will become extremely slow, as the bottleneck will become the DataLoader. That's because, without caching, every time ClinicalDataset is queried, it will re-preprocess and re-create 3D images from scratch. The solution below solves the problem. For perspective, without caching, loading a single sample takes ~1.5 seconds. With caching, ~6 millisencods.
#
# Another solution would be just hold all 3D images on CPU memory, as they require approx 3.7 GB with the parameters I used in preprocessing pipeline, and transfer them to GPU/TPU when needed. May be even faster. I will experiment with that later.

# %%
class ClinicalDataset(Dataset):
    def __init__(self, root_dir, ctscans_dir, mode, transform=None,
                 cache_dir=None):
        self.transform = transform
        self.mode = mode
        self.ctscans_dir = Path(ctscans_dir)
        self.cache_dir = None if cache_dir is None else Path(cache_dir)
        # print(self.cache_dir)
        # If cache_dir is set, use cached values...
        if cache_dir is not None:
            self.raw = pd.read_csv(self.cache_dir/f'tabular_{mode}.csv')
            # print(self.raw)
            with open(self.cache_dir/'features_list.pkl', "rb") as fp:
                self.FE = pickle.load(fp)
                # print(self.FE)
            return 

        # ...otherwise, pre-process
        tr = pd.read_csv(Path(root_dir)/"train.csv")
        tr.drop_duplicates(keep=False, inplace=True, subset=['Patient', 'Weeks'])
        chunk = pd.read_csv(Path(root_dir)/"test.csv")

        sub = pd.read_csv(Path(root_dir)/"sample_submission.csv")
        sub['Patient'] = sub['Patient_Week'].apply(lambda x: x.split('_')[0])
        sub['Weeks'] = sub['Patient_Week'].apply(lambda x: int(x.split('_')[-1]))
        sub = sub[['Patient', 'Weeks', 'Confidence', 'Patient_Week']]
        sub = sub.merge(chunk.drop('Weeks', axis=1), on="Patient")

        tr['WHERE'] = 'train'
        chunk['WHERE'] = 'val'
        sub['WHERE'] = 'test'
        data = tr.append([chunk, sub])

        data['min_week'] = data['Weeks']
        data.loc[data.WHERE == 'test', 'min_week'] = np.nan
        data['min_week'] = data.groupby('Patient')['min_week'].transform('min')

        base = data.loc[data.Weeks == data.min_week]
        base = base[['Patient', 'FVC']].copy()
        base.columns = ['Patient', 'min_FVC']
        base['nb'] = 1
        base['nb'] = base.groupby('Patient')['nb'].transform('cumsum')
        base = base[base.nb == 1]
        base.drop('nb', axis=1, inplace=True)

        data = data.merge(base, on='Patient', how='left')
        data['base_week'] = data['Weeks'] - data['min_week']
        # print(base)
        del base

        COLS = ['Sex', 'SmokingStatus']
        self.FE = []
        for col in COLS:
            for mod in data[col].unique():
                self.FE.append(mod)
                data[mod] = (data[col] == mod).astype(int)

        data['age'] = (data['Age'] - data['Age'].min()) / \
                      (data['Age'].max() - data['Age'].min())
        data['BASE'] = (data['min_FVC'] - data['min_FVC'].min()) / \
                       (data['min_FVC'].max() - data['min_FVC'].min())
        data['week'] = (data['base_week'] - data['base_week'].min()) / \
                       (data['base_week'].max() - data['base_week'].min())
        data['percent'] = (data['Percent'] - data['Percent'].min()) / \
                          (data['Percent'].max() - data['Percent'].min())
        self.FE += ['age', 'percent', 'week', 'BASE']

        self.raw = data.loc[data.WHERE == mode].reset_index()
        del data
        # return getitem

    def __len__(self):
        return len(self.raw)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        patient_id = self.raw['Patient'].iloc[idx]
        if self.cache_dir is None:
            patient_path = self.ctscans_dir / patient_id
            image, metadata = load_scan(patient_path)
        else:
            image = torch.load(self.cache_dir / f'{patient_id}.pt')
            metadata = pydicom.read_file(self.cache_dir / f'{patient_id}.dcm')

        sample = {
            'features': self.raw[self.FE].iloc[idx].values,
            'image': image,
            'metadata': metadata,
            'target': self.raw['FVC'].iloc[idx]
        }
        if self.transform:
            sample = self.transform(sample)
        # print(sample)
        return sample

    def cache(self, cache_dir):
        Path(cache_dir).mkdir(exist_ok=True, parents=True)

        # Cache raw features table
        self.raw.to_csv(Path(cache_dir)/f'tabular_{self.mode}.csv', index=False)

        # Cache features list
        with open(Path(cache_dir)/'features_list.pkl', "wb") as fp:
            pickle.dump(self.FE, fp)

        # Cache images and metadata
        self.raw['index'] = self.raw.index
        idx_unique = self.raw.groupby('Patient').first()['index'].values
        bar = tqdm(idx_unique.tolist())
        for idx in bar:
            sample = self[idx]
            patient_id = sample['metadata'].PatientID
            torch.save(sample['image'], Path(cache_dir)/f'{patient_id}.pt')
            sample['metadata'].save_as(Path(cache_dir)/f'{patient_id}.dcm')

# %%
# Helper function that loads CT scans in a single array. 
# This is also new vs. baselie
def load_scan(path):
    slices = [pydicom.read_file(p) for p in path.glob('*.dcm')]
    try:
        slices.sort(key=lambda x: float(x.ImagePositionPatient[2]))
    except AttributeError:
        warnings.warn(f'Patient {slices[0].PatientID} CT scan does not '
                      f'have "ImagePositionPatient". Assuming filenames '
                      f'in the right scan order.')

    image = np.stack([s.pixel_array.astype(float) for s in slices])
    return image, slices[0]

# %% [markdown]
# ## 3.1. Preprocessing CT Scans
#
# This section is new vs. the baseline notebook. It builds on a lot of great work done by several Kagglers (I'll make an effort and cite everyone).

# %% [markdown]
# ### 3.1.1. Crop bounding boxes

# %%
class CropBoundingBox:
    @staticmethod
    def bounding_box(img3d: np.array):
        mid_img = img3d[int(img3d.shape[0] / 2)]
        same_first_row = (mid_img[0, :] == mid_img[0, 0]).all()
        same_first_col = (mid_img[:, 0] == mid_img[0, 0]).all()
        if same_first_col and same_first_row:
            return True
        else:
            return False

    def __call__(self, sample):
        image = sample['image']
        if not self.bounding_box(image):
            return sample

        mid_img = image[int(image.shape[0] / 2)]
        r_min, r_max = None, None
        c_min, c_max = None, None
        for row in range(mid_img.shape[0]):
            if not (mid_img[row, :] == mid_img[0, 0]).all() and r_min is None:
                r_min = row
            if (mid_img[row, :] == mid_img[0, 0]).all() and r_max is None \
                    and r_min is not None:
                r_max = row
                break

        for col in range(mid_img.shape[1]):
            if not (mid_img[:, col] == mid_img[0, 0]).all() and c_min is None:
                c_min = col
            if (mid_img[:, col] == mid_img[0, 0]).all() and c_max is None \
                    and c_min is not None:
                c_max = col
                break

        image = image[:, r_min:r_max, c_min:c_max]
        return {
            'features': sample['features'],
            'image': image,
            'metadata': sample['metadata'],
            'target': sample['target']
        }

# %% [markdown]
# ### 3.1.2. Convert to Hounsfield Units
# Getting to the code below was really painful. Credits to lots of people.

# %%
class ConvertToHU:
    def __call__(self, sample):
        image, data = sample['image'], sample['metadata']

        img_type = data.ImageType
        is_hu = img_type[0] == 'ORIGINAL' and not (img_type[2] == 'LOCALIZER')
        if not is_hu:
            warnings.warn(f'Patient {data.PatientID} CT Scan not cannot be'
                          f'converted to Hounsfield Units (HU).')

        intercept = data.RescaleIntercept
        slope = data.RescaleSlope
        image = (image * slope + intercept).astype(np.int16)
        return {
            'features': sample['features'],
            'image': image,
            'metadata': data,
            'target': sample['target']
        }

# %% [markdown]
# ### 3.1.3. Resize

# %%
class Resize:
    def __init__(self, output_size):
        assert isinstance(output_size, tuple)
        self.output_size = output_size

    def __call__(self, sample):
        image = sample['image']
        resize_factor = np.array(self.output_size) / np.array(image.shape)
        image = zoom(image, resize_factor, mode='nearest')
        return {
            'features': sample['features'],
            'image': image,
            'metadata': sample['metadata'],
            'target': sample['target']
        }

# %% [markdown]
# ### 3.1.4. Clip

# %%
class Clip:
    def __init__(self, bounds=(-1000, 500)):
        self.min = min(bounds)
        self.max = max(bounds)

    def __call__(self, sample):
        image = sample['image']
        image[image < self.min] = self.min
        image[image > self.max] = self.max
        return {
            'features': sample['features'],
            'image': image,
            'metadata': sample['metadata'],
            'target': sample['target']
        }

# %% [markdown]
# ### 3.1.5 Mask
# Here I basically tried 2 different methods: one [morphological](https://www.kaggle.com/miklgr500/unsupervise-lung-detection), and one using [Deep Learning](https://github.com/JoHof/lungmask). The deep learning method is extremely slow, so we go for the morphological path. The deep learning method is incomplete (thus the `raise NotImplementedError` in the code below).
#
# Credits to @[Michael Kazachok](https://www.kaggle.com/miklgr500).

# %%
class MaskMethod(Enum):
    MORPHOLOGICAL = 1
    DEEPLEARNING = 2


class Mask:
    def __init__(self, method=MaskMethod.MORPHOLOGICAL, threshold=-400,
                 root_dir='../data/test'):
        self.threshold = threshold
        self.method = method
        self.root_dir = root_dir

    def __call__(self, sample):
        image = sample['image']
        if self.method == MaskMethod.MORPHOLOGICAL:
            for slice_id in range(image.shape[0]):
                m = self.get_morphological_mask(image[slice_id])
                image[slice_id][m == False] = image[slice_id].min()
        elif self.method == MaskMethod.DEEPLEARNING:
            # m = self.get_deeplearning_mask(data.PatientID)
            raise NotImplementedError
        else:
            raise ValueError('Unrecognized masking method')

        return {
            'features': sample['features'],
            'image': image,
            'metadata': sample['metadata'],
            'target': sample['target']
        }

    def get_morphological_mask(self, image):
        m = image < self.threshold
        m = clear_border(m)
        m = label(m)
        areas = [r.area for r in regionprops(m)]
        areas.sort()
        if len(areas) > 2:
            for region in regionprops(m):
                if region.area < areas[-2]:
                    for coordinates in region.coords:
                        m[coordinates[0], coordinates[1]] = 0
        return m > 0

    def get_deeplearning_mask(self, patient_id):
        """Very slow, must be done using GPUs
        """
        list_files = [str(x) for x in (Path(self.root_dir) / patient_id).glob('*.dcm')]
        input_image = sitk.ReadImage(list_files)
        m = mask.apply(input_image) #.squeeze()
        m[m == 2] = 1
        return m

# %% [markdown]
# ### 3.1.6. Normalize, to tensor and zero center

# %%
class Normalize:
    def __init__(self, bounds=(-1000, 500)):
        self.min = min(bounds)
        self.max = max(bounds)

    def __call__(self, sample):
        image = sample['image'].astype(np.float)
        image = (image - self.min) / (self.max - self.min)
        return {
            'features': sample['features'],
            'image': image,
            'metadata': sample['metadata'],
            'target': sample['target']
        }


class ToTensor:
    def __init__(self, add_channel=True):
        self.add_channel = add_channel

    def __call__(self, sample):
        image = sample['image']
        if self.add_channel:
            image = np.expand_dims(image, axis=0)

        return {
            'features': sample['features'],
            'image': torch.from_numpy(image),
            'metadata': sample['metadata'],
            'target': sample['target']
        }

    
class ZeroCenter:
    def __init__(self, pre_calculated_mean):
        self.pre_calculated_mean = pre_calculated_mean

    def __call__(self, sample):
        return {
            'features': sample['features'],
            'image': sample['image'] - self.pre_calculated_mean,
            'metadata': sample['metadata'],
            'target': sample['target']
        }

# %% [markdown]
# ## 3.2. Checking the data pipeline
# Before moving forward, let's ensure the data pipeline works

# %%
# def show(list_imgs, cmap=cm.bone, rgb=False):
#     list_slices = []
#     for img3d in list_imgs:
#         slc = int(img3d.shape[0] / 2)
#         img = img3d[slc]
#         if rgb:
#             img = (img * 255).astype(np.int16)
#         list_slices.append(img)
    
#     fig, axs = plt.subplots(1, 5, figsize=(15, 7))
#     for i, img in enumerate(list_slices):
#         axs[i].imshow(img, cmap=cmap)
    
#     plt.show()

# %%
# data = ClinicalDataset(
#     root_dir=root_dir,
#     ctscans_dir='/content/test',
#     mode='val',
#     transform=transforms.Compose([
#         CropBoundingBox(),
#         ConvertToHU(),
#         Resize((40, 256, 256)),
#         Clip(bounds=(-1000, 500)),
#         Mask(method=MaskMethod.MORPHOLOGICAL, threshold=-500),
#         Normalize(bounds=(-1000, -500))
#     ]))

# for i in range(len(data)):
#     assert data[i]['image'].shape == (40, 256, 256)
    
# list_imgs = [data[i]['image'] for i in range(len(data))]
# show(list_imgs)

# %%
data = ClinicalDataset(
    root_dir=root_dir,
    ctscans_dir='/content/test',
    mode='val',
    transform=transforms.Compose([
        CropBoundingBox(),
        ConvertToHU(),
        Resize((40, 256, 256)),
        Clip(bounds=(-1000, 500)),
        Mask(method=MaskMethod.MORPHOLOGICAL, threshold=-500),
        Normalize(bounds=(-1000, -500)),
        ToTensor(),
        ZeroCenter(pre_calculated_mean=0.029105728564346046)
    ]))

means = []
for i in range(len(data)):
    means.append(data[i]['image'].mean())

assert np.mean(means) == pytest.approx(0, abs=2e-3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: Patient ID00421637202311550012437 CT Scan not cannot beconverted to Hounsfield Units (HU).

# %% [markdown]
# # 4. Models and loss
# The differences vs. the baseline notebook are highlighted in the code.

# %% [markdown]
# ## 4.1. Quant model

# %%
class QuantModel(nn.Module):
    def __init__(self, in_tabular_features=9, in_ctscan_features=76800,
                 out_quantiles=3):
        super(QuantModel, self).__init__()
        # This line is new. We need to know a priori the number
        # of latent features to properly flatten the tensor
        self.in_ctscan_features = in_ctscan_features

        self.fc1 = nn.Linear(in_tabular_features, 512)
        self.fc2 = nn.Linear(in_ctscan_features, 512)
        self.fc3 = nn.Linear(1024, 512)
        self.fc4 = nn.Linear(512, out_quantiles)

    def forward(self, x1, x2):
        # Now the quant model has 2 inputs: x1 (the tabular features)
        # and x2 (the pre-computed latent features)
        x1 = F.relu(self.fc1(x1))
        
        # Flattens the latent features and concatenate with tabular features
        x2 = x2.view(-1, self.in_ctscan_features)
        x2 = F.relu(self.fc2(x2))
        x = torch.cat([x1, x2], dim=1)
        
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %% [markdown]
# ## 4.2. Quant loss
# No news here vs. baseline notebook. Again, credits to [Ceshine Lee's quantile regression tutorial](https://medium.com/the-artificial-impostor/quantile-regression-part-2-6fdbc26b2629).

# %%
def quantile_loss(preds, target, quantiles):
    assert not target.requires_grad
    assert preds.size(0) == target.size(0)
    losses = []
    for i, q in enumerate(quantiles):
        errors = target - preds[:, i]
        losses.append(torch.max((q - 1) * errors, q * errors).unsqueeze(1))
    loss = torch.mean(torch.sum(torch.cat(losses, dim=1), dim=1))
    return loss

# %% [markdown]
# ## 4.3. AutoEncoder
# This is new vs. baseline notebook. As mentioned, the auto-encoder was pre-trained in another notebook. I won't include the pre-training code here otherwise this notebook will become even larger.
#
# Credits to [Srinjay Paul's 3D Convolutional autoencoder for brain volumes tutorial](https://srinjaypaul.github.io/3D_Convolutional_autoencoder_for_brain_volumes/).

# %%
class AutoEncoder(nn.Module):
    def __init__(self):
        super(AutoEncoder, self).__init__()
        # Encoder
        self.conv1 = nn.Conv3d(1, 16, 3)
        self.conv2 = nn.Conv3d(16, 32, 3)
        self.conv3 = nn.Conv3d(32, 96, 2)
        self.pool1 = nn.MaxPool3d(kernel_size=2, stride=2, return_indices=True)
        self.pool2 = nn.MaxPool3d(kernel_size=3, stride=3, return_indices=True)
        self.pool3 = nn.MaxPool3d(kernel_size=2, stride=2, return_indices=True)
        # Decoder
        self.deconv1 = nn.ConvTranspose3d(96, 32, 2)
        self.deconv2 = nn.ConvTranspose3d(32, 16, 3)
        self.deconv3 = nn.ConvTranspose3d(16, 1, 3)
        self.unpool1 = nn.MaxUnpool3d(kernel_size=2, stride=2)
        self.unpool2 = nn.MaxUnpool3d(kernel_size=3, stride=3)
        self.unpool3 = nn.MaxUnpool3d(kernel_size=2, stride=2)

    def encode(self, x, return_partials=True):
        # Encoder
        x = self.conv1(x)
        up3out_shape = x.shape
        x, i1 = self.pool1(x)
        x = self.conv2(x)
        up2out_shape = x.shape
        x, i2 = self.pool2(x)
        x = self.conv3(x)
        up1out_shape = x.shape
        x, i3 = self.pool3(x)

        if return_partials:
            return x, up3out_shape, i1, up2out_shape, i2, up1out_shape, i3
        else:
            return x

    def forward(self, x):
        x, up3out_shape, i1, up2out_shape, i2, up1out_shape, i3 = self.encode(x)

        # Decoder
        x = self.unpool1(x, output_size=up1out_shape, indices=i3)
        x = self.deconv1(x)
        x = self.unpool2(x, output_size=up2out_shape, indices=i2)
        x = self.deconv2(x)
        x = self.unpool3(x, output_size=up3out_shape, indices=i1)
        x = self.deconv3(x)

        return x

# %% [markdown]
# ## 4.4. Cache all pre-processed 3D CT Scans and pre-compute all latent features
# It takes ~15 minutes to pre-process all 3D CT scan. To accelerate, I already pre-cached the dataset and made it available in [this public dataset](https://www.kaggle.com/carlossouza/osic-cached-dataset). If you want to do it, the code to cache the dataset is `dataset.cache(cache_dir)`.
#
# With the dataset cached, let's pre-compute all latent features. (Not pre-computing them would lead to very slow training...):

# %%
# Helper function that generates all latent features
class GenerateLatentFeatures:
    def __init__(self, autoencoder, latent_dir):
        self.autoencoder = autoencoder
        self.latent_dir = Path(latent_dir)
        self.cache_dir = Path(cache_dir)

    def __call__(self, sample):
        patient_id = sample['metadata'].PatientID
        cached_latent_file = self.latent_dir/f'{patient_id}_lat.pt'

        if cached_latent_file.is_file():
            latent_features = torch.load(cached_latent_file)
        else:
            with torch.no_grad():
                img = sample['image'].float().unsqueeze(0)
                latent_features = self.autoencoder.encode(
                    img, return_partials=False).squeeze(0)
            torch.save(latent_features, cached_latent_file)

        return {
            'tabular_features': sample['features'],
            'latent_features': latent_features,
            'target': sample['target']
        }

# %%
# data = ClinicalDataset(
#     root_dir=root_dir,
#     ctscans_dir=root_dir/'train',
#     mode='train',
#     transform=transforms.Compose([
#         CropBoundingBox(),
#         ConvertToHU(),
#         Resize((40, 256, 256)),
#         Clip(bounds=(-1000, 500)),
#         Mask(method=MaskMethod.MORPHOLOGICAL, threshold=-500),
#         Normalize(bounds=(-1000, -500)),
#         ToTensor(),
#         ZeroCenter(pre_calculated_mean=0.029105728564346046)
#     ])).cache(cache_dir)

# %% [markdown]
# The code below loops through all samples in the dataset, pre-computes the latent features, and cache them in disk as well.

# %%
autoencoder = AutoEncoder()
autoencoder.load_state_dict(torch.load(
    pretrained_ae_weigths,
    map_location=torch.device('cpu')
))
device = torch.device('cpu')
autoencoder.to(device)
autoencoder.eval()

data = ClinicalDataset(
    root_dir=root_dir,
    ctscans_dir=root_dir/'train',
    cache_dir=cache_dir,
    mode='train',
    transform=GenerateLatentFeatures(autoencoder, latent_dir)
)
# len(data[0])
for i in trange(len(data)):
    sample = data[i]
    assert sample['latent_features'].shape == (96, 2, 20, 20)
  # try:
  #     sample = data[i]
  #     assert sample['latent_features'].shape == (96, 2, 20, 20)
  # except:
  #     print("sheriyayilledo")
# Out:
#  25%|██▌       | 390/1535 [00:19<00:54, 21.01it/s]

# %% [markdown]
# ## 4.5. Overfit a small batch before moving forward
# As observed by Andrej Karpathy ([A Recipe for Training Neural Networks](http://karpathy.github.io/2019/04/25/recipe/)), neural net training fail silently. Before moving to full blown training, let's overfit a small batch: if we observe the loss decreasing, it is a sign that we probably did not make any obvious mistakes so far.

# %%
dataloader = DataLoader(data, batch_size=batch_size,
                        shuffle=True, num_workers=2)
batch = next(iter(dataloader))
device = torch.device('cpu')
model = QuantModel().to(device)
# model = QuantModel()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

bar = trange(50)
for epoch in bar:
    inputs1 = batch['tabular_features'].float().to(device)
    inputs2 = batch['latent_features'].float().to(device)
    targets = batch['target'].to(device)

    optimizer.zero_grad()
    preds = model(inputs1, inputs2)
    loss = quantile_loss(preds, targets, quantiles)
    loss.backward()
    if use_TPU:
        xm.optimizer_step(optimizer, barrier=True)
    else:
        optimizer.step()
    

    bar.set_postfix(loss=f'{loss.item():0.1f}')

# %% [markdown]
# # 5. Training
# I made 2 main changes here:
# 1. Code is adjusted to run on TPU. It is not optimized (uses only 1 of the 8 cores), but does the job... Anyway, the last version does everything on CPU
# 2. It is NOT doing Kfold CV. Code is back to doing simple Group Shuffle split. Main reason is that I did not see noticeable improvement from doing a simple split vs. KFold. When we were only using tabular data, no problem doing 5 folds. Now, every fold takes some time. As next step, an idea would be run every fold in parallel, in one of the 8 TPU cores, as I saw in one of the TPU tutorials. But that's for later

# %%
# Helper generator that group splits
def group_split(dataset, groups, test_size=0.2):
    gss = GroupShuffleSplit(n_splits=1, test_size=test_size)
    idx = list(gss.split(dataset.raw, dataset.raw, groups))
    train = Subset(dataset, idx[0][0])
    val = Subset(dataset, idx[0][1])
    return train, val
        
# Helper function with competition metric
def metric(preds, targets):
    sigma = preds[:, 2] - preds[:, 0]
    sigma[sigma < 70] = 70
    delta = (preds[:, 1] - targets).abs()
    delta[delta > 1000] = 1000
    return -np.sqrt(2) * delta / sigma - torch.log(np.sqrt(2) * sigma)

# %%
# Load the data
autoencoder = AutoEncoder()
autoencoder.load_state_dict(torch.load(
    pretrained_ae_weigths,
    map_location=torch.device('cpu')
))
autoencoder.eval()

data = ClinicalDataset(
    root_dir=root_dir,
    ctscans_dir=root_dir/'train',
    cache_dir=cache_dir,
    mode='train',
    transform=GenerateLatentFeatures(autoencoder, latent_dir)
)

trainset, valset = group_split(data, data.raw['Patient'], test_size)
t0 = time()

# Prepare to save model weights
Path(model_dir).mkdir(parents=True, exist_ok=True)
now = datetime.now()
fname = f'{model_name}-{now.year}{now.month:02d}{now.day:02d}.pth'
model_file = Path(model_dir) / fname

dataset_sizes = {'train': len(trainset), 'val': len(valset)}
dataloaders = {
    'train': DataLoader(trainset, batch_size=batch_size,
                        shuffle=True, num_workers=2),
    'val': DataLoader(valset, batch_size=batch_size,
                      shuffle=False, num_workers=2)
}

# Create the model and optimizer
model = QuantModel().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Set global tracking variables
epoch_loss = {'train': np.inf, 'val': np.inf}
epoch_metric = {'train': -np.inf, 'val': -np.inf}
best_loss = np.inf
best_model_wts = None
df = pd.DataFrame(columns=['epoch', 'train_loss', 'val_loss'])

# Training loop
for epoch in range(num_epochs):
    for phase in ['train', 'val']:
        if phase == 'train':
            model.train()  # Set model to training mode
        else:
            model.eval()   # Set model to evaluate mode

        running_loss = 0.0
        running_metric = 0.0

        # Iterate over data
        num_samples = 0
        bar = tqdm(dataloaders[phase])
        for batch in bar:
            bar.set_description(f'Epoch {epoch} {phase}'.ljust(20))
            inputs1 = batch['tabular_features'].float().to(device)
            inputs2 = batch['latent_features'].float().to(device)
            targets = batch['target'].to(device)

            # zero the parameter gradients
            optimizer.zero_grad()
            # forward
            # track gradients if only in train
            with torch.set_grad_enabled(phase == 'train'):
                preds = model(inputs1, inputs2)
                loss = quantile_loss(preds, targets, quantiles)
                # backward + optimize only if in training phase
                if phase == 'train':
                    loss.backward()
                    if use_TPU:
                        xm.optimizer_step(optimizer, barrier=True)
                    else:
                        optimizer.step()

            running_loss += loss.item() * inputs1.size(0)
            running_metric += metric(preds, targets).sum()

            # batch statistics
            num_samples += inputs1.size(0)
            # bar.set_postfix(loss=f'{running_loss / num_samples:0.1f}',
            #                 metric=f'{running_metric / num_samples:0.4f}')

        # epoch statistics
        epoch_loss[phase] = running_loss / dataset_sizes[phase]
        epoch_metric[phase] = running_metric / dataset_sizes[phase]

        # deep copy the model
        if phase == 'val' and epoch_loss['val'] < best_loss:
            best_loss = epoch_loss['val']
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(best_model_wts, model_file)

    df = df.append({
        'epoch': epoch + 1,
        'train_loss': epoch_loss["train"],
        'val_loss': epoch_loss["val"]
    }, ignore_index=True)

# Save training statistics
fname = f'{model_name}-{now.year}{now.month:02d}{now.day:02d}.csv'
csv_file = Path(model_dir) / fname
df.to_csv(csv_file, index=False)

# load best model weights
model.load_state_dict(best_model_wts)

print(f'Training complete! Time: {timedelta(seconds=time() - t0)}')
models = [model]

# %% [markdown]
# # 6. Generating submission CSV
# No change vs. baseline notebook

# %%
data = ClinicalDataset(
    root_dir=root_dir,
    ctscans_dir=root_dir/'test',
    mode='test',
    transform=transforms.Compose([
        CropBoundingBox(),
        ConvertToHU(),
        Resize((40, 256, 256)),
        Clip(bounds=(-1000, 500)),
        Mask(method=MaskMethod.MORPHOLOGICAL, threshold=-500),
        Normalize(bounds=(-1000, -500)),
        ToTensor(),
        ZeroCenter(pre_calculated_mean=0.029105728564346046)
    ]))

# data.cache(latent_dir)

# %%
data = ClinicalDataset(
    root_dir=root_dir,
    ctscans_dir=root_dir/'test',
    cache_dir=latent_dir,
    mode='test',
    transform=GenerateLatentFeatures(autoencoder, latent_dir)
)

avg_preds = np.zeros((len(data), len(quantiles)))
print(len(data), len(quantiles),avg_preds)
for model in models:
    dataloader = DataLoader(data, batch_size=batch_size,shuffle=False, num_workers=2)
    preds = []
    for batch in tqdm(dataloader):
        inputs1 = batch['tabular_features'].float()
        inputs1 = inputs1.to(device)
        inputs2 = batch['latent_features'].float()
        inputs2 = inputs2.to(device)
        with torch.no_grad():
            preds.append(model(inputs1, inputs2))

    preds = torch.cat(preds, dim=0).cpu().numpy()
    avg_preds += preds

avg_preds /= len(models)
df = pd.DataFrame(data=avg_preds, columns=list(quantiles))
df['Patient_Week'] = data.raw['Patient_Week']
df['FVC'] = df[quantiles[1]]
df['Confidence'] = df[quantiles[2]] - df[quantiles[0]]
df = df.drop(columns=list(quantiles))
df.to_csv('submission.csv', index=False)

# %%
print(len(df))
df.head()

# %% [markdown]
# # 7. Conclusions and next steps
# - The process is working, end-to-end
# - However, it is very slow... need to figure out how to accelerate
# - Need to experiment/tune hyperparameters to improve metric
# - The final steps are very ugly, should refactor
